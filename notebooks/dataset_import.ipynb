# %% [markdown]
# <a href="https://colab.research.google.com/github/mlcodr/Fraud_Detection/blob/main/notebooks/dataset_import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Standard Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
print(f"Last Updated: {datetime.datetime.now()}")
# Out:
# Last Updated: 2026-05-04 18:06:29.571153

# %%
## Importing credit card fraud dataset
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud")
# Out:
# ...
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: joint-gradient
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# ...
# 100%|██████████| 66.0M/66.0M [00:00<00:00, 116MB/s]

# %%
fraud_data  = pd.read_csv("/content/creditcardfraud/creditcard.csv")

# %%
fraud_data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %% [markdown]
# **About The Dataset**
#
#
# *   Time (in seconds) since first transaction
# *   v1 - v28 : These are PCA-transformed features
# * Amount : Actual transaction amount
# * **Class** : 0-> Normal Transactions , 1-> Fraud Transaction
#
# * Very Imbalanced datasets\
#   0 → 284,315 \
#   1 → 492 (0.17% of the whole dataset)
